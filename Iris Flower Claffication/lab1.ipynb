# %%
# !pip install numpy pandas matplotlib scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Requirement already satisfied: scikit-learn in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\sathi\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
print("hellow world")
# Out:
# hellow world

# %%
print("welcome to the lab of AI")
# Out:
# welcome to the lab of AI

# %%
print("Radhey Radhey")
# Out:
# Radhey Radhey

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("iris.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
print(df.head())
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.sample(10)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 44             5.1           3.8            1.9           0.4      Iris-setosa
# 20             5.4           3.4            1.7           0.2      Iris-setosa
# 48             5.3           3.7            1.5           0.2      Iris-setosa
# 114            5.8           2.8            5.1           2.4   Iris-virginica
# 92             5.8           2.6            4.0           1.2  Iris-versicolor
# 105            7.6           3.0            6.6           2.1   Iris-virginica
# 109            7.2           3.6            6.1           2.5   Iris-virginica
# 139            6.9           3.1            5.4           2.1   Iris-virginica
# 110            6.5           3.2            5.1           2.0   Iris-virginica
# 102            7.1           3.0            5.9           2.1   Iris-virginica

# %%
#check for missing value
print(df.isnull())
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
print(df.isnull().sum())
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
count=df["Species"].value_counts()
print(count)
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
count=df["Species"].value_counts()
plt.Figure(figsize=(6,5))
plt.bar(x=count.index,height=count.values)
plt.xlabel("Iris Species")
plt.ylabel("Frequency")
plt.title("Iris Species vs Count")
plt.savefig("Iris Species vs Count")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
#split the data set into x and y
x=df.drop(columns=['Species'])
y=df['Species']
x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2,random_state=42
)
print(f"length of x_train and y_train={x_train.shape}{y_train.shape}")
print(f"length of x_test and y_test={x_test.shape}{y_test.shape}")
# Out:
# length of x_train and y_train=(120, 4)(120,)
# length of x_test and y_test=(30, 4)(30,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_preds=knn.predict(x_test)
print(f"Accuracy= {accuracy_score(y_test,y_preds)}")
print(f"classification Report\n{classification_report(y_test,y_preds)}")
# Out:
# Accuracy= 1.0
# classification Report
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %%
cm=confusion_matrix(y_test,y_preds)
cm_plot=ConfusionMatrixDisplay(
    confusion_matrix=cm,display_labels=df['Species'].unique()
)
cm_plot.plot()
plt.savefig("cm.png")
plt.show()

# %%
import joblib
joblib.dump(knn,"knn_model.joblib")
print("success")
# Out:
# success

# %%
sample=x_test.sample()
print(sample)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 78            6.0           2.9            4.5           1.5

# %%
sample=x_test.sample()
sample_preds=knn.predict(sample)
print(sample_preds[0])
# Out:
# Iris-virginica
